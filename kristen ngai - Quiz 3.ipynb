# %% [markdown]
# # <span style="color:red"> QTM 151 - Quiz 3 </span>

# %% [markdown]
# ## Please submit as an HTML file

# %% [markdown]
# <font size = "5" >
# This quiz is open book
#
# - You can use the lecture notes
# - You will get partial credit for attempting the questions
# - To get full credit, the code should run as intended
# - You should <span style="color:red"> NOT </span> communicate with other students
#
# Print the following message: <br>
#
# "I will abide by Emory's code of conduct"

# %%
# Write your answer here:

print("I will abide by Emory's code of conduct")

# %% [markdown]
# <font size = "5">
#
# Import the libraries "numpy" and "pandas"

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# <font size = "5">
#
# (1) Replace values in a column
#
# <font size = "3">
#
# - Load the data from "constructors.csv", assigning it to a DataFrame.
# - In the "nationality" column, replace the values "British", "Japanese", and "Irish" with "UK", "Japan", and "Ireland", respectively.
# - For full credit, do this by using the ``.replace`` command **one time**

# %%
# Your answer here
df_constructor = pd.read_csv('C:/Users/ngaik/Downloads/constructors.csv')
df_constructor['nationality'] = df_constructor['nationality'].replace(
    {'British': 'UK', 'Japanese': 'Japan', 'Irish': 'Ireland'}
)
print(df_constructor)
# Out:
#      constructorId constructorRef            name nationality  \
# 0                1        mclaren         McLaren          UK
# 1                2     bmw_sauber      BMW Sauber      German
# 2                3       williams        Williams          UK
# 3                4        renault         Renault      French
# 4                5     toro_rosso      Toro Rosso     Italian
# ..             ...            ...             ...         ...
# 206            209          manor  Manor Marussia          UK
# 207            210           haas    Haas F1 Team    American
# 208            211   racing_point    Racing Point          UK
# 209            213     alphatauri      AlphaTauri     Italian
# 210            214         alpine  Alpine F1 Team      French
#
#                                                    url
# 0                 http://en.wikipedia.org/wiki/McLaren
# 1              http://en.wikipedia.org/wiki/BMW_Sauber
# 2    http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# 3    http://en.wikipedia.org/wiki/Renault_in_Formul...
# 4     http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso
# ..                                                 ...
# 206      http://en.wikipedia.org/wiki/Manor_Motorsport
# 207          http://en.wikipedia.org/wiki/Haas_F1_Team
# 208  http://en.wikipedia.org/wiki/Racing_Point_F1_Team
# 209   http://en.wikipedia.org/wiki/Scuderia_AlphaTauri
# 210        http://en.wikipedia.org/wiki/Alpine_F1_Team
#
# [211 rows x 5 columns]

# %% [markdown]
# <font size = "5">
#
# (2) Aggregate and query
#
# <font size = "3">
#
# Import the data from "sprint_results.csv" and assign it to a DataFrame. Do the following:
#
# - Extract the subset corresponding to 'constructorId == 51' using ```.query()```
# - Group by the column "driverId", and then aggregate the maximum over the "laps" column for each driver.
# - Extract the subset of drivers with maximum of laps $\ge 20$. Assign this to a DataFrame with a name of your choice.
#
# For full credit, perform all the steps in bullet points above in a **single line** using chaining. (If you use line breaks or wrap in parentheses it doesn't literally need to be one line).
#
# **Hint:** I only see your final submission, not the code you wrote along the way. It might be easier to break it up into multiple lines, then combine when you're done.

# %%
# Your answer here
df_sprint = pd.read_csv('C:/Users/ngaik/Downloads/sprint_results.csv')

subset = (
    df_sprint[df_sprint['laps'] >= 20]   
      .query('constructorId == 51')                             
      .groupby('driverId', as_index=False)        
      .agg(max_laps=('laps', 'max'))                            
)

print(subset.head())
# Out:
#    driverId  max_laps
# 0         8        24
# 1       822        24
# 2       841        24
# 3       855        24

# %% [markdown]
# <font size = "5">
#
# (3) Recode a numeric column
#
# <font size = "3">
#
# - Import data from "races.csv" and assign it to a DataFrame
# - Recode the "year" column into a new column "year_brackets"
# with the following categories
#
# $\qquad$ ``` ["1950-1965","1966-1980","1981-onwards"] ```
#
# The easiest method is ``pd.cut()`` but you are not required to use this.

# %%
# Your answer here

df_races = pd.read_csv('C:/Users/ngaik/Downloads/races.csv')

df_races = df_races.rename(columns={'year': 'year_brackets'})

df_races['year'] = pd.cut(
    df_races['year_brackets'],
    bins=[1949, 1965, 1980, float('inf')],
    labels=['1950-1965', '1966-1980', '1981-onwards']
)
print(df_races)
# Out:
#       raceId  year_brackets  round  circuitId                      name  \
# 0          1           2009      1          1     Australian Grand Prix
# 1          2           2009      2          2      Malaysian Grand Prix
# 2          3           2009      3         17        Chinese Grand Prix
# 3          4           2009      4          3        Bahrain Grand Prix
# 4          5           2009      5          4        Spanish Grand Prix
# ...      ...            ...    ...        ...                       ...
# 1097    1116           2023     19         69  United States Grand Prix
# 1098    1117           2023     20         32    Mexico City Grand Prix
# 1099    1118           2023     21         18      São Paulo Grand Prix
# 1100    1119           2023     22         80      Las Vegas Grand Prix
# 1101    1120           2023     23         24      Abu Dhabi Grand Prix
#
#             date      time                                                url  \
# 0      3/29/2009   6:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...
# 1       4/5/2009   9:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...
# 2      4/19/2009   7:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...
# 3      4/26/2009  12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...
# 4      5/10/2009  12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Gran...
# ...          ...       ...                                                ...
# 1097  10/22/2023  19:00:00  https://en.wikipedia.org/wiki/2023_United_Stat...
# 1098  10/29/2023  20:00:00  https://en.wikipedia.org/wiki/2023_Mexico_City...
# 1099   11/5/2023  17:00:00  https://en.wikipedia.org/wiki/2023_S%C3%A3o_Pa...
# 1100  11/19/2023   6:00:00  https://en.wikipedia.org/wiki/2023_Las_Vegas_G...
# 1101  11/26/2023  13:00:00  https://en.wikipedia.org/wiki/2023_Abu_Dhabi_G...
#
#         fp1_date  fp1_time    fp2_date  fp2_time    fp3_date  fp3_time  \
# 0             \N        \N          \N        \N          \N        \N
# 1             \N        \N          \N        \N          \N        \N
# 2             \N        \N          \N        \N          \N        \N
# 3             \N        \N          \N        \N          \N        \N
# 4             \N        \N          \N        \N          \N        \N
# ...          ...       ...         ...       ...         ...       ...
# 1097  10/20/2023  17:30:00  10/21/2023  18:00:00          \N        \N
# 1098  10/27/2023  18:30:00  10/27/2023  22:00:00  10/28/2023  17:30:00
# 1099   11/3/2023  14:30:00   11/4/2023  14:30:00          \N        \N
# 1100  11/17/2023   4:30:00  11/17/2023   8:00:00  11/18/2023   4:30:00
# 1101  11/24/2023   9:30:00  11/24/2023  13:00:00  11/25/2023  10:30:00
#
#       quali_date quali_time sprint_date sprint_time          year
# 0             \N         \N          \N          \N  1981-onwards
# 1             \N         \N          \N          \N  1981-onwards
# 2             \N         \N          \N          \N  1981-onwards
# 3             \N         \N          \N          \N  1981-onwards
# 4             \N         \N          \N          \N  1981-onwards
# ...          ...        ...         ...         ...           ...
# 1097  10/20/2023   21:00:00  10/21/2023    22:00:00  1981-onwards
# 1098  10/28/2023   21:00:00          \N          \N  1981-onwards
# 1099   11/3/2023   18:00:00   11/4/2023    18:30:00  1981-onwards
# 1100  11/18/2023    8:00:00          \N          \N  1981-onwards
# 1101  11/25/2023   14:00:00          \N          \N  1981-onwards
#
# [1102 rows x 19 columns]

# %% [markdown]
# <font size = "5">
#
# (4) Aggregate and sort
#
# <font size = "3">
#
# Import the data from "sprint_results.csv" and assign it to a DataFrame (or use the same DataFrame you created in problem (2)). Do the following:
#
# - Group by "driverId", and then aggregate the average (mean) over the "laps" column.
# - Sort the teams by average laps in **descending** order using ``.sort_values()``. Assign this to a DataFrame with a name of your choice.
#
# For full credit, perform both steps in bullet points above in a **single line** using chaining. (If you use line breaks or wrap in parentheses it doesn't literally need to be one line).
#
# **Hint:** Same hint as problem 2. You can chain commands together later.

# %%
# Your answer here

result = (
    df_sprint.groupby('driverId', as_index=False)['laps']
      .agg(['mean'])
      .sort_values(by='mean', ascending=False)
)

print(result)
# Out:
#     driverId       mean
# 8        825  22.666667
# 0          1  21.166667
# 10       832  21.166667
# 22       854  21.166667
# 20       852  21.166667
# 19       849  21.166667
# 17       847  21.166667
# 16       846  21.166667
# 15       844  21.166667
# 11       839  21.166667
# 12       840  21.166667
# 9        830  21.166667
# 7        822  21.166667
# 6        817  21.166667
# 5        815  21.000000
# 4         20  20.833333
# 2          8  20.500000
# 13       841  19.666667
# 21       853  19.666667
# 18       848  18.666667
# 14       842  18.166667
# 3          9  18.000000
# 1          4  17.333333
# 23       855  15.666667

# %% [markdown]
# <font size = "5">
#
# (5) Rename column
#
# <font size = "3">
#
# - Import the data from "sprint_results.csv" and assign it to a DataFrame (or use the same DataFrame you created in problem (2))
#
# - Rename the column "time" to "time_unformatted". The names of the other columns should be left intact.
#
# - Print (or display) the DataFrame to ensure the column was renamed correctly.

# %%
# Your answer here

df_sprint =  df_sprint.rename(columns={'time': 'time_unformatted'})
print(df_sprint.head())
# Out:
#    resultId  raceId  driverId  constructorId  number  grid position  \
# 0         1    1061       830              9      33     2        1
# 1         2    1061         1            131      44     1        2
# 2         3    1061       822            131      77     3        3
# 3         4    1061       844              6      16     4        4
# 4         5    1061       846              1       4     6        5
#
#   positionText  positionOrder  points  laps time_unformatted milliseconds  \
# 0            1              1       3    17          25:38.4      1538426
# 1            2              2       2    17             1.43      1539856
# 2            3              3       1    17            7.502      1545928
# 3            4              4       0    17           11.278      1549704
# 4            5              5       0    17           24.111      1562537
#
#   fastestLap fastestLapTime  statusId
# 0         14        01:30.0         1
# 1         17        01:29.9         1
# 2         17        01:30.0         1
# 3         16        01:30.2         1
# 4         16        01:30.6         1

# %% [markdown]
# <font size = "5">
#
# (6) Merge dataset
#
# <font size = "3">
#
# - Import the data from "sprint_results.csv" and "constructors.csv", assigning them to two DataFrames (you can also re-use the DataFrames you created above.)
#
# - Create a new dataset with  ``pd.merge()``. Treat "sprint_results.csv" as the primary dataset and "constructors.csv" as the secondary dataset. The merge should be based on the column "constructorId".
# the column "constructorId"
# - To get full credit **ONLY** merge the "nationality" column from the secondary dataset (not all the columns)
# - Print (or display) the resulting merged DataFrame to the screen.
#
# **Hint**: Before you start typing "pd.merge(...)" try printing out the two DataFrames you want to merge, excluding any columns that shouldn't be included.

# %%
# Your answer here


merged = df_sprint.merge(df_constructor[['constructorId', 'nationality']], on='constructorId', how='left')
print(merged.head())
# Out:
#    resultId  raceId  driverId  constructorId  number  grid position  \
# 0         1    1061       830              9      33     2        1
# 1         2    1061         1            131      44     1        2
# 2         3    1061       822            131      77     3        3
# 3         4    1061       844              6      16     4        4
# 4         5    1061       846              1       4     6        5
#
#   positionText  positionOrder  points  laps time_unformatted milliseconds  \
# 0            1              1       3    17          25:38.4      1538426
# 1            2              2       2    17             1.43      1539856
# 2            3              3       1    17            7.502      1545928
# 3            4              4       0    17           11.278      1549704
# 4            5              5       0    17           24.111      1562537
#
#   fastestLap fastestLapTime  statusId nationality
# 0         14        01:30.0         1    Austrian
# 1         17        01:29.9         1      German
# 2         17        01:30.0         1      German
# 3         16        01:30.2         1     Italian
# 4         16        01:30.6         1          UK
